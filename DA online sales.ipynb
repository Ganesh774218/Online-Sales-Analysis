# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
data=pd.read_csv("New_online_sales.csv")
data
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38  01-01-2020 00:00
# 1         771155  SKU_1241     White Mug        18  01-01-2020 01:00
# 2         231932  SKU_1501    Headphones        49  01-01-2020 02:00
# 3         465838  SKU_1760     Desk Lamp        14  01-01-2020 03:00
# 4         359178  SKU_1386     USB Cable       -30  01-01-2020 04:00
# ...          ...       ...           ...       ...               ...
# 49777     354083  SKU_1562      Blue Pen        25  05-09-2025 01:00
# 49778     296698  SKU_1930     USB Cable         7  05-09-2025 02:00
# 49779     177622  SKU_1766  Office Chair        43  05-09-2025 03:00
# 49780     701213  SKU_1602      Notebook        48  05-09-2025 04:00
# 49781     772215  SKU_1832     White Mug        30  05-09-2025 05:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49782 entries, 0 to 49781
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   InvoiceNo          49782 non-null  int64
#  1   StockCode          49782 non-null  object
#  2   Description        49782 non-null  object
#  3   Quantity           49782 non-null  int64
#  4   InvoiceDate        49782 non-null  object
#  5   UnitPrice          49782 non-null  float64
#  6   CustomerID         44804 non-null  float64
#  7   Country            49782 non-null  object
#  8   Discount           49782 non-null  float64
#  9   PaymentMethod      49782 non-null  object
#  10  ShippingCost       47293 non-null  float64
#  11  Category           49782 non-null  object
#  12  SalesChannel       49782 non-null  object
#  13  ReturnStatus       49782 non-null  object
#  14  ShipmentProvider   49782 non-null  object
#  15  WarehouseLocation  46297 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# InvoiceNo               0
# StockCode               0
# Description             0
# Quantity                0
# InvoiceDate             0
# UnitPrice               0
# CustomerID           4978
# Country                 0
# Discount                0
# PaymentMethod           0
# ShippingCost         2489
# Category                0
# SalesChannel            0
# ReturnStatus            0
# ShipmentProvider        0
# WarehouseLocation    3485
# OrderPriority           0
# DateTime                0
# dtype: int64

# %%
data.tail()
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 49777     354083  SKU_1562      Blue Pen        25  05-09-2025 01:00
# 49778     296698  SKU_1930     USB Cable         7  05-09-2025 02:00
# 49779     177622  SKU_1766  Office Chair        43  05-09-2025 03:00
# 49780     701213  SKU_1602      Notebook        48  05-09-2025 04:00
# 49781     772215  SKU_1832     White Mug        30  05-09-2025 05:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# 49777      70.92     51445.0           Spain      0.20    Credit Card
# 49778      51.74     28879.0   United States      0.23  Bank Transfer
# 49779      85.25     21825.0        Portugal      0.20  Bank Transfer
# 49780      39.64     43199.0  United Kingdom      0.31        paypall
# 49781      38.27     53328.0          France      0.10    Credit Card
#
#        ShippingCost     Category SalesChannel  ReturnStatus ShipmentProvider  \
# ...

# %%
data.dropna(inplace=True)
data
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38  01-01-2020 00:00
# 1         771155  SKU_1241     White Mug        18  01-01-2020 01:00
# 2         231932  SKU_1501    Headphones        49  01-01-2020 02:00
# 3         465838  SKU_1760     Desk Lamp        14  01-01-2020 03:00
# 5         744167  SKU_1006  Office Chair        47  01-01-2020 05:00
# ...          ...       ...           ...       ...               ...
# 49777     354083  SKU_1562      Blue Pen        25  05-09-2025 01:00
# 49778     296698  SKU_1930     USB Cable         7  05-09-2025 02:00
# 49779     177622  SKU_1766  Office Chair        43  05-09-2025 03:00
# 49780     701213  SKU_1602      Notebook        48  05-09-2025 04:00
# 49781     772215  SKU_1832     White Mug        30  05-09-2025 05:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %%
data.isnull().sum()
# Out:
# InvoiceNo            0
# StockCode            0
# Description          0
# Quantity             0
# InvoiceDate          0
# UnitPrice            0
# CustomerID           0
# Country              0
# Discount             0
# PaymentMethod        0
# ShippingCost         0
# Category             0
# SalesChannel         0
# ReturnStatus         0
# ShipmentProvider     0
# WarehouseLocation    0
# OrderPriority        0
# DateTime             0
# dtype: int64

# %%
data[data["CustomerID"].isnull()]
data
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38  01-01-2020 00:00
# 1         771155  SKU_1241     White Mug        18  01-01-2020 01:00
# 2         231932  SKU_1501    Headphones        49  01-01-2020 02:00
# 3         465838  SKU_1760     Desk Lamp        14  01-01-2020 03:00
# 5         744167  SKU_1006  Office Chair        47  01-01-2020 05:00
# ...          ...       ...           ...       ...               ...
# 49777     354083  SKU_1562      Blue Pen        25  05-09-2025 01:00
# 49778     296698  SKU_1930     USB Cable         7  05-09-2025 02:00
# 49779     177622  SKU_1766  Office Chair        43  05-09-2025 03:00
# 49780     701213  SKU_1602      Notebook        48  05-09-2025 04:00
# 49781     772215  SKU_1832     White Mug        30  05-09-2025 05:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %%
a=data.count().max()
print(a)
# Out:
# 44804

# %%
data.dtypes
# Out:
# InvoiceNo              int64
# StockCode             object
# Description           object
# Quantity               int64
# InvoiceDate           object
# UnitPrice            float64
# CustomerID           float64
# Country               object
# Discount             float64
# PaymentMethod         object
# ShippingCost         float64
# Category              object
# SalesChannel          object
# ReturnStatus          object
# ShipmentProvider      object
# WarehouseLocation     object
# OrderPriority         object
# DateTime              object
# dtype: object

# %%
# Step 1: Parse the datetime with correct settings
data["InvoiceDate"] = pd.to_datetime(data["InvoiceDate"], dayfirst=True, errors='coerce')

# Step 2: Extract only the date part
data["InvoiceDate"] = data["InvoiceDate"].dt.date
data
# Out:
#        InvoiceNo StockCode   Description  Quantity InvoiceDate  UnitPrice  \
# 0         221958  SKU_1964     White Mug        38  2020-01-01       1.71
# 1         771155  SKU_1241     White Mug        18  2020-01-01      41.25
# 2         231932  SKU_1501    Headphones        49  2020-01-01      29.11
# 3         465838  SKU_1760     Desk Lamp        14  2020-01-01      76.68
# 5         744167  SKU_1006  Office Chair        47  2020-01-01      70.16
# ...          ...       ...           ...       ...         ...        ...
# 49777     354083  SKU_1562      Blue Pen        25  2025-09-05      70.92
# 49778     296698  SKU_1930     USB Cable         7  2025-09-05      51.74
# 49779     177622  SKU_1766  Office Chair        43  2025-09-05      85.25
# 49780     701213  SKU_1602      Notebook        48  2025-09-05      39.64
# 49781     772215  SKU_1832     White Mug        30  2025-09-05      38.27
#
#        CustomerID         Country  Discount  PaymentMethod  ShippingCost  \
# ...

# %%
data.drop("DateTime",axis=1,inplace=True)
data
# Out:
#        InvoiceNo StockCode   Description  Quantity InvoiceDate  UnitPrice  \
# 0         221958  SKU_1964     White Mug        38  2020-01-01       1.71
# 1         771155  SKU_1241     White Mug        18  2020-01-01      41.25
# 2         231932  SKU_1501    Headphones        49  2020-01-01      29.11
# 3         465838  SKU_1760     Desk Lamp        14  2020-01-01      76.68
# 5         744167  SKU_1006  Office Chair        47  2020-01-01      70.16
# ...          ...       ...           ...       ...         ...        ...
# 49777     354083  SKU_1562      Blue Pen        25  2025-09-05      70.92
# 49778     296698  SKU_1930     USB Cable         7  2025-09-05      51.74
# 49779     177622  SKU_1766  Office Chair        43  2025-09-05      85.25
# 49780     701213  SKU_1602      Notebook        48  2025-09-05      39.64
# 49781     772215  SKU_1832     White Mug        30  2025-09-05      38.27
#
#        CustomerID         Country  Discount  PaymentMethod  ShippingCost  \
# ...

# %%
data.isnull().sum()
# Out:
# InvoiceNo            0
# StockCode            0
# Description          0
# Quantity             0
# InvoiceDate          0
# UnitPrice            0
# CustomerID           0
# Country              0
# Discount             0
# PaymentMethod        0
# ShippingCost         0
# Category             0
# SalesChannel         0
# ReturnStatus         0
# ShipmentProvider     0
# WarehouseLocation    0
# OrderPriority        0
# DateTime             0
# dtype: int64

# %%
data.to_csv("New_online_sales",index=False)

# %%
data.to_csv(r'C:\Users\ganesh r. gawde\OneDrive\Desktop\Data anlysis project\New_sales_data.csv', index=False)

# %%
import os

file_path = r'D:\DataCleaning\Output\New_sales_data.csv'

if os.path.exists(file_path):
    print("✅ File saved successfully!")
else:
    print("❌ File not found. Check folder path and permissions.")
# Out:
# ❌ File not found. Check folder path and permissions.
